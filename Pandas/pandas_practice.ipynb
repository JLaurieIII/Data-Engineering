# %%
import pandas as pd

# %%
a = [1,2,3,4,5]
ser = pd.Series(a, ["x", "y", "z", "a", "b"])
ser
# Out:
# x    1
# y    2
# z    3
# a    4
# b    5
# dtype: int64

# %%
b = pd.Series(a)
b
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
df = pd.DataFrame(b)

# %%
df
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
dic = {"name":["Nagendra", "Jimmy", "Leonard", "Platini", "Nuredin"], "salary":[2341324,23413242,23546,457346,2435234]}

# %%
dic
# Out:
# {'name': ['Nagendra', 'Jimmy', 'Leonard', 'Platini', 'Nuredin'],
#  'salary': [2341324, 23413242, 23546, 457346, 2435234]}

# %%
df = pd.DataFrame(dic)

# %%
df
# Out:
#        name    salary
# 0  Nagendra   2341324
# 1     Jimmy  23413242
# 2   Leonard     23546
# 3   Platini    457346
# 4   Nuredin   2435234

# %%
df["salary"]
# Out:
# 0     2341324
# 1    23413242
# 2       23546
# 3      457346
# 4     2435234
# Name: salary, dtype: int64

# %%
df['salary'].sum()
# Out:
# 28670692

# %%
df = pd.read_excel("edw-demo-01.xlsx")

# %%
df
# Out:
#     Loan Number Advance Date    Lender  Borrower  Collateral  Initial Balance  \
# 0        804812   2018-04-04  FRSTUS44         1           1          1425000
# 1   201-9376056   2018-04-05  WFBIUS6S         2           2          1075000
# 2   201-0468768   2018-04-06  WFBIUS6S         3           3           475000
# 3        043171   2018-04-07  FRSTUS44         4           4           825000
# 4   201-0704971   2018-04-08  WFBIUS6S         5           5           950000
# 5        646568   2018-04-09  FRSTUS44         6           6           825000
# 6     100043437   2018-04-10  BOFAUS3N         7           7           900000
# 7   201-2379278   2018-04-11  WFBIUS6S         8           8          1075000
# 8        161696   2018-04-12  FRSTUS44         9           9          1175000
# 9     656363533   2018-04-13  CHASUS33        10          10           300000
# 10    440844225   2018-04-14  CHASUS33        11          11          1350000
# ...

# %%
df.head(5)
# Out:
#    Loan Number Advance Date    Lender  Borrower  Collateral  Initial Balance  \
# 0       804812   2018-04-04  FRSTUS44         1           1          1425000
# 1  201-9376056   2018-04-05  WFBIUS6S         2           2          1075000
# 2  201-0468768   2018-04-06  WFBIUS6S         3           3           475000
# 3       043171   2018-04-07  FRSTUS44         4           4           825000
# 4  201-0704971   2018-04-08  WFBIUS6S         5           5           950000
#
#    Maturity (Years)
# 0                30
# 1                30
# 2                15
# 3                30
# 4                30

# %%
df.tail(5)
# Out:
#     Loan Number Advance Date    Lender  Borrower  Collateral  Initial Balance  \
# 35       033085   2018-05-09  FRSTUS44        36          36          1325000
# 36  201-1005757   2018-05-10  WFBIUS6S        37          37          1000000
# 37       225182   2018-05-11  FRSTUS44        38          38          1375000
# 38  201-4035040   2018-05-12  WFBIUS6S        39          39          1300000
# 39  201-0903795   2018-05-13  WFBIUS6S        40          40           525000
#
#     Maturity (Years)
# 35                15
# 36                30
# 37                15
# 38                15
# 39                30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Loan Number       40 non-null     object
#  1   Advance Date      40 non-null     datetime64[ns]
#  2   Lender            40 non-null     object
#  3   Borrower          40 non-null     int64
#  4   Collateral        40 non-null     int64
#  5   Initial Balance   40 non-null     int64
#  6   Maturity (Years)  40 non-null     int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 2.3+ KB

# %%
df.isnull()
# Out:
#     Loan Number  Advance Date  Lender  Borrower  Collateral  Initial Balance  \
# 0         False         False   False     False       False            False
# 1         False         False   False     False       False            False
# 2         False         False   False     False       False            False
# 3         False         False   False     False       False            False
# 4         False         False   False     False       False            False
# 5         False         False   False     False       False            False
# 6         False         False   False     False       False            False
# 7         False         False   False     False       False            False
# 8         False         False   False     False       False            False
# 9         False         False   False     False       False            False
# 10        False         False   False     False       False            False
# ...

# %%
df.isnull().sum()
# Out:
# Loan Number         0
# Advance Date        0
# Lender              0
# Borrower            0
# Collateral          0
# Initial Balance     0
# Maturity (Years)    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Loan Number', 'Advance Date', 'Lender', 'Borrower', 'Collateral',
#        'Initial Balance', 'Maturity (Years)'],
#       dtype='object')

# %%
df[["Maturity (Years)","Lender","Loan Number"]]
# Out:
#     Maturity (Years)    Lender  Loan Number
# 0                 30  FRSTUS44       804812
# 1                 30  WFBIUS6S  201-9376056
# 2                 15  WFBIUS6S  201-0468768
# 3                 30  FRSTUS44       043171
# 4                 30  WFBIUS6S  201-0704971
# 5                 30  FRSTUS44       646568
# 6                 30  BOFAUS3N    100043437
# 7                 30  WFBIUS6S  201-2379278
# 8                 30  FRSTUS44       161696
# 9                 30  CHASUS33    656363533
# 10                15  CHASUS33    440844225
# 11                30  BOFAUS3N    100044970
# 12                30  WFBIUS6S  201-1449237
# 13                30  CHASUS33    900915558
# 14                15  FRSTUS44       258224
# 15                30  BOFAUS3N    100086125
# 16                30  CHASUS33    756871271
# 17                30  WFBIUS6S  201-1579782
# 18                15  BOFAUS3N    100041577
# 19                30  WFBIUS6S  201-1509316
# ...

# %%
import pandas as pd

# %%
customers = pd.read_csv('Mall_Customers.csv')

# %%
customers
# Out:
#      CustomerID   Genre   Age  Annual_Income_(k$)  Spending_Score
# 0             1     NaN   NaN                15.0             NaN
# 1             2    Male  21.0                 NaN            81.0
# 2             3     NaN   NaN                16.0             6.0
# 3             4  Female  23.0                16.0            77.0
# 4             5  Female   NaN                17.0            40.0
# ..          ...     ...   ...                 ...             ...
# 195         196  Female  35.0               120.0            79.0
# 196         197  Female  45.0               126.0            28.0
# 197         198    Male  32.0               126.0            74.0
# 198         199    Male  32.0               137.0            18.0
# 199         200    Male  30.0               137.0            83.0
#
# [200 rows x 5 columns]

# %%
new = customers.dropna()
new
# Out:
#      CustomerID   Genre   Age  Annual_Income_(k$)  Spending_Score
# 3             4  Female  23.0                16.0            77.0
# 5             6  Female  22.0                17.0            76.0
# 6             7  Female  35.0                18.0             6.0
# 7             8  Female  23.0                18.0            94.0
# 8             9    Male  64.0                19.0             3.0
# ..          ...     ...   ...                 ...             ...
# 195         196  Female  35.0               120.0            79.0
# 196         197  Female  45.0               126.0            28.0
# 197         198    Male  32.0               126.0            74.0
# 198         199    Male  32.0               137.0            18.0
# 199         200    Male  30.0               137.0            83.0
#
# [195 rows x 5 columns]
